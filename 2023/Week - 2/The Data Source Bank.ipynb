# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'PD 2023 Wk 1 Input.csv', 'The Data Source Bank.ipynb']

# %%
df = pd.read_csv("PD 2023 Wk 1 Input.csv")

# %%
df.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person  \
# 0  DTB-716-679-576   1448         100001                    2
# 1   DS-795-814-303   7839         100001                    2
# 2  DSB-807-592-406   5520         100005                    1
# 3   DS-367-545-264   7957         100007                    2
# 4  DSB-474-374-857   5375         100000                    2
#
#       Transaction Date
# 0  20/03/2023 00:00:00
# 1  15/11/2023 00:00:00
# 2  14/07/2023 00:00:00
# 3  18/08/2023 00:00:00
# 4  26/08/2023 00:00:00

# %%
df.dtypes
# Out:
# Transaction Code       object
# Value                   int64
# Customer Code           int64
# Online or In-Person     int64
# Transaction Date       object
# dtype: object

# %%
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"], format = "%d/%m/%Y %H:%M:%S")

# %%
df.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person Transaction Date
# 0  DTB-716-679-576   1448         100001                    2       2023-03-20
# 1   DS-795-814-303   7839         100001                    2       2023-11-15
# 2  DSB-807-592-406   5520         100005                    1       2023-07-14
# 3   DS-367-545-264   7957         100007                    2       2023-08-18
# 4  DSB-474-374-857   5375         100000                    2       2023-08-26

# %%
df.dtypes
# Out:
# Transaction Code               object
# Value                           int64
# Customer Code                   int64
# Online or In-Person             int64
# Transaction Date       datetime64[ns]
# dtype: object

# %%
df[["Bank" , "Col-1", "Col-2","Col-3"]] = df["Transaction Code"].str.split("-",expand = True)

# %%
df.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person  \
# 0  DTB-716-679-576   1448         100001                    2
# 1   DS-795-814-303   7839         100001                    2
# 2  DSB-807-592-406   5520         100005                    1
# 3   DS-367-545-264   7957         100007                    2
# 4  DSB-474-374-857   5375         100000                    2
#
#   Transaction Date Bank Col-1 Col-2 Col-3
# 0       2023-03-20  DTB   716   679   576
# 1       2023-11-15   DS   795   814   303
# 2       2023-07-14  DSB   807   592   406
# 3       2023-08-18   DS   367   545   264
# 4       2023-08-26  DSB   474   374   857

# %% [markdown]
# ## Output - 1

# %%
df1 = df[["Bank","Value"]]

# %%
df1_op= df.groupby(df["Bank"],as_index =False)["Value"].sum()

# %%
df1_op.head()
# Out:
#   Bank   Value
# 0   DS  653940
# 1  DSB  530489
# 2  DTB  618238

# %% [markdown]
# #### --------------------------

# %%
df.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person  \
# 0  DTB-716-679-576   1448         100001                    2
# 1   DS-795-814-303   7839         100001                    2
# 2  DSB-807-592-406   5520         100005                    1
# 3   DS-367-545-264   7957         100007                    2
# 4  DSB-474-374-857   5375         100000                    2
#
#   Transaction Date Bank Col-1 Col-2 Col-3
# 0       2023-03-20  DTB   716   679   576
# 1       2023-11-15   DS   795   814   303
# 2       2023-07-14  DSB   807   592   406
# 3       2023-08-18   DS   367   545   264
# 4       2023-08-26  DSB   474   374   857

# %%
df["Online or In-Person"] = np.where(df["Online or In-Person"] == 1 , "Online" , "In-Person")

# %%
df.head()
# Out:
#   Transaction Code  Value  Customer Code Online or In-Person Transaction Date  \
# 0  DTB-716-679-576   1448         100001           In-Person       2023-03-20
# 1   DS-795-814-303   7839         100001           In-Person       2023-11-15
# 2  DSB-807-592-406   5520         100005              Online       2023-07-14
# 3   DS-367-545-264   7957         100007           In-Person       2023-08-18
# 4  DSB-474-374-857   5375         100000           In-Person       2023-08-26
#
#   Bank Col-1 Col-2 Col-3
# 0  DTB   716   679   576
# 1   DS   795   814   303
# 2  DSB   807   592   406
# 3   DS   367   545   264
# 4  DSB   474   374   857

# %%
df["Transaction Date"] = df["Transaction Date"].dt.day_name()

# %%
df.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person  \
# 0  DTB-716-679-576   1448         100001                    2
# 1   DS-795-814-303   7839         100001                    2
# 2  DSB-807-592-406   5520         100005                    1
# 3   DS-367-545-264   7957         100007                    2
# 4  DSB-474-374-857   5375         100000                    2
#
#   Transaction Date Bank Col-1 Col-2 Col-3
# 0           Monday  DTB   716   679   576
# 1        Wednesday   DS   795   814   303
# 2           Friday  DSB   807   592   406
# 3           Friday   DS   367   545   264
# 4         Saturday  DSB   474   374   857

# %% [markdown]
# ## Output - 2

# %%
df2_op =  df.groupby(['Bank','Online or In-Person','Transaction Date'],as_index=False)['Value'].sum()

# %%
df2_op.head()
# Out:
#   Bank Online or In-Person Transaction Date  Value
# 0   DS           In-Person           Friday  58599
# 1   DS           In-Person           Monday  42806
# 2   DS           In-Person         Saturday  34867
# 3   DS           In-Person           Sunday  51301
# 4   DS           In-Person         Thursday  75582

# %% [markdown]
# ## Output - 3

# %%
df3_op = df.groupby(['Bank', "Customer Code"] , as_index = False)['Value'].sum()

# %%
df3_op.head()
# Out:
#   Bank  Customer Code  Value
# 0   DS         100000  57909
# 1   DS         100001  53063
# 2   DS         100002  69803
# 3   DS         100003  25482
# 4   DS         100004  63315

# %% [markdown]
# ## ------------------------------------------------------------------------------------------------------------------------

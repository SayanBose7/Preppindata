# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# [' The Prep School - Parental Contact Details.ipynb',
#  '.ipynb_checkpoints',
#  'PD 2022 Wk 1 Input - Input.csv']

# %%
df = pd.read_csv("PD 2022 Wk 1 Input - Input.csv")

# %%
df.head()
# Out:
#    id pupil first name pupil last name  gender Date of Birth  \
# 0   1            Ronna         Nellies  Female    12/21/2013
# 1   2            Rusty       Andriulis    Male     7/21/2012
# 2   3          Roberta       Oakeshott  Female     12/4/2011
# 3   4             Lola       Rubinfajn    Male     6/29/2012
# 4   5           Kamila        Benedtti  Female     7/10/2012
#
#   Parental Contact Name_1 Parental Contact Name_2 Preferred Contact Employer  \
# 0                 Purcell                   Ketti                     Demizz
# 1                 Vassili                    Rivi                   Brainbox
# 2                    Lind                 Haskell                   Centidel
# 3                    Elie                   Tresa                   Edgeblab
# 4                   Adela                  Clevey                     Trudoo
#
#    Parental Contact
# 0                 1
# 1                 1
# 2                 2
# 3                 2
# 4                 1

# %%
df1 = df

# %%
df2 = df

# %%
df.dtypes
# Out:
# id                             int64
# pupil first name              object
# pupil last name               object
# gender                        object
# Date of Birth                 object
# Parental Contact Name_1       object
# Parental Contact Name_2       object
# Preferred Contact Employer    object
# Parental Contact               int64
# dtype: object

# %%
df1["Pupil's Name"] = df1["pupil last name"] + "," +df1["pupil first name"]

# %%
df1["Pupil's Name"]
# Out:
# 0          Nellies,Ronna
# 1        Andriulis,Rusty
# 2      Oakeshott,Roberta
# 3         Rubinfajn,Lola
# 4        Benedtti,Kamila
#              ...
# 995      Worling,Ninetta
# 996      Tinton,Stanford
# 997        MacCook,Ertha
# 998       Randles,Lawton
# 999     Pashbee,Engracia
# Name: Pupil's Name, Length: 1000, dtype: object

# %%
df1.head()
# Out:
#    id pupil first name pupil last name  gender Date of Birth  \
# 0   1            Ronna         Nellies  Female    12/21/2013
# 1   2            Rusty       Andriulis    Male     7/21/2012
# 2   3          Roberta       Oakeshott  Female     12/4/2011
# 3   4             Lola       Rubinfajn    Male     6/29/2012
# 4   5           Kamila        Benedtti  Female     7/10/2012
#
#   Parental Contact Name_1 Parental Contact Name_2 Preferred Contact Employer  \
# 0                 Purcell                   Ketti                     Demizz
# 1                 Vassili                    Rivi                   Brainbox
# 2                    Lind                 Haskell                   Centidel
# 3                    Elie                   Tresa                   Edgeblab
# 4                   Adela                  Clevey                     Trudoo
#
#    Parental Contact       Pupil's Name
# 0                 1      Nellies,Ronna
# 1                 1    Andriulis,Rusty
# 2                 2  Oakeshott,Roberta
# 3                 2     Rubinfajn,Lola
# 4                 1    Benedtti,Kamila

# %%
df1["Parental Contact Full Name"] = df1[["pupil last name","Parental Contact Name_1"]].apply(",".join,axis = 1)

# %%
df1["Parental Contact Full Name"]
# Out:
# 0        Nellies,Purcell
# 1      Andriulis,Vassili
# 2         Oakeshott,Lind
# 3         Rubinfajn,Elie
# 4         Benedtti,Adela
#              ...
# 995       Worling,Sibbie
# 996          Tinton,Kyle
# 997      MacCook,Sidonia
# 998         Randles,Kali
# 999       Pashbee,Emlynn
# Name: Parental Contact Full Name, Length: 1000, dtype: object

# %%
df1.head(10)
# Out:
#    id pupil first name pupil last name  gender Date of Birth  \
# 0   1            Ronna         Nellies  Female    12/21/2013
# 1   2            Rusty       Andriulis    Male     7/21/2012
# 2   3          Roberta       Oakeshott  Female     12/4/2011
# 3   4             Lola       Rubinfajn    Male     6/29/2012
# 4   5           Kamila        Benedtti  Female     7/10/2012
# 5   6            Avery       Colebourn  Female     8/30/2012
# 6   7        Valentino          Klimko  Female    12/23/2014
# 7   8              Cal       Shearwood    Male     1/18/2015
# 8   9             King        Truswell  Female     9/14/2012
# 9  10           Towney        Stichall    Male      6/4/2015
#
#   Parental Contact Name_1 Parental Contact Name_2 Preferred Contact Employer  \
# 0                 Purcell                   Ketti                     Demizz
# 1                 Vassili                    Rivi                   Brainbox
# 2                    Lind                 Haskell                   Centidel
# 3                    Elie                   Tresa                   Edgeblab
# 4                   Adela                  Clevey                     Trudoo
# 5                 Dalenna                 Charley                   Linktype
# 6                 Arlette                Onofredo                Thoughtblab
# 7                Leontine                   Berne                 Browseblab
# 8                    Evvy                 Othelia                 Photospace
# 9                  Wendie                  Joyann                    Kwimbee
#
#    Parental Contact       Pupil's Name Parental Contact Full Name
# 0                 1      Nellies,Ronna            Nellies,Purcell
# 1                 1    Andriulis,Rusty          Andriulis,Vassili
# 2                 2  Oakeshott,Roberta             Oakeshott,Lind
# 3                 2     Rubinfajn,Lola             Rubinfajn,Elie
# 4                 1    Benedtti,Kamila             Benedtti,Adela
# 5                 1    Colebourn,Avery          Colebourn,Dalenna
# 6                 2   Klimko,Valentino             Klimko,Arlette
# 7                 2      Shearwood,Cal         Shearwood,Leontine
# 8                 1      Truswell,King              Truswell,Evvy
# 9                 2    Stichall,Towney            Stichall,Wendie

# %%
df1["Parental Contact Email Address"] = df1["Parental Contact Name_1"]+"."+df1["pupil last name"]+"@"+df1["Preferred Contact Employer"]+".com"

# %%
df1["Parental Contact Email Address"]
# Out:
# 0          Purcell.Nellies@Demizz.com
# 1      Vassili.Andriulis@Brainbox.com
# 2         Lind.Oakeshott@Centidel.com
# 3         Elie.Rubinfajn@Edgeblab.com
# 4           Adela.Benedtti@Trudoo.com
#                     ...
# 995           Sibbie.Worling@Omba.com
# 996          Kyle.Tinton@Dabshots.com
# 997    Sidonia.MacCook@Topicshots.com
# 998          Kali.Randles@Skalith.com
# 999       Emlynn.Pashbee@Zoomzone.com
# Name: Parental Contact Email Address, Length: 1000, dtype: object

# %%
df1.head()
# Out:
#    id pupil first name pupil last name  gender Date of Birth  \
# 0   1            Ronna         Nellies  Female    12/21/2013
# 1   2            Rusty       Andriulis    Male     7/21/2012
# 2   3          Roberta       Oakeshott  Female     12/4/2011
# 3   4             Lola       Rubinfajn    Male     6/29/2012
# 4   5           Kamila        Benedtti  Female     7/10/2012
#
#   Parental Contact Name_1 Parental Contact Name_2 Preferred Contact Employer  \
# 0                 Purcell                   Ketti                     Demizz
# 1                 Vassili                    Rivi                   Brainbox
# 2                    Lind                 Haskell                   Centidel
# 3                    Elie                   Tresa                   Edgeblab
# 4                   Adela                  Clevey                     Trudoo
#
#    Parental Contact       Pupil's Name Parental Contact Full Name  \
# 0                 1      Nellies,Ronna            Nellies,Purcell
# 1                 1    Andriulis,Rusty          Andriulis,Vassili
# 2                 2  Oakeshott,Roberta             Oakeshott,Lind
# 3                 2     Rubinfajn,Lola             Rubinfajn,Elie
# 4                 1    Benedtti,Kamila             Benedtti,Adela
#
#    Parental Contact Email Address
# 0      Purcell.Nellies@Demizz.com
# 1  Vassili.Andriulis@Brainbox.com
# 2     Lind.Oakeshott@Centidel.com
# 3     Elie.Rubinfajn@Edgeblab.com
# 4       Adela.Benedtti@Trudoo.com

# %%
df1["Date of Birth"] =pd.to_datetime(df1["Date of Birth"])

# %%
df1.dtypes
# Out:
# id                                         int64
# pupil first name                          object
# pupil last name                           object
# gender                                    object
# Date of Birth                     datetime64[ns]
# Parental Contact Name_1                   object
# Parental Contact Name_2                   object
# Preferred Contact Employer                object
# Parental Contact                           int64
# Pupil's Name                              object
# Parental Contact Full Name                object
# Parental Contact Email Address            object
# dtype: object

# %%
df1['Academic Year'] = 2015 - df1['Date of Birth'].apply(lambda x: x.year if x.month >= 9 else x.year-1)

# %%
df1.head(10)
# Out:
#    id pupil first name pupil last name  gender Date of Birth  \
# 0   1            Ronna         Nellies  Female    2013-12-21
# 1   2            Rusty       Andriulis    Male    2012-07-21
# 2   3          Roberta       Oakeshott  Female    2011-12-04
# 3   4             Lola       Rubinfajn    Male    2012-06-29
# 4   5           Kamila        Benedtti  Female    2012-07-10
# 5   6            Avery       Colebourn  Female    2012-08-30
# 6   7        Valentino          Klimko  Female    2014-12-23
# 7   8              Cal       Shearwood    Male    2015-01-18
# 8   9             King        Truswell  Female    2012-09-14
# 9  10           Towney        Stichall    Male    2015-06-04
#
#   Parental Contact Name_1 Parental Contact Name_2 Preferred Contact Employer  \
# 0                 Purcell                   Ketti                     Demizz
# 1                 Vassili                    Rivi                   Brainbox
# 2                    Lind                 Haskell                   Centidel
# 3                    Elie                   Tresa                   Edgeblab
# 4                   Adela                  Clevey                     Trudoo
# 5                 Dalenna                 Charley                   Linktype
# 6                 Arlette                Onofredo                Thoughtblab
# 7                Leontine                   Berne                 Browseblab
# 8                    Evvy                 Othelia                 Photospace
# 9                  Wendie                  Joyann                    Kwimbee
#
#    Parental Contact       Pupil's Name Parental Contact Full Name  \
# 0                 1      Nellies,Ronna            Nellies,Purcell
# 1                 1    Andriulis,Rusty          Andriulis,Vassili
# 2                 2  Oakeshott,Roberta             Oakeshott,Lind
# 3                 2     Rubinfajn,Lola             Rubinfajn,Elie
# 4                 1    Benedtti,Kamila             Benedtti,Adela
# 5                 1    Colebourn,Avery          Colebourn,Dalenna
# 6                 2   Klimko,Valentino             Klimko,Arlette
# 7                 2      Shearwood,Cal         Shearwood,Leontine
# 8                 1      Truswell,King              Truswell,Evvy
# 9                 2    Stichall,Towney            Stichall,Wendie
#
#       Parental Contact Email Address  Academic Year
# 0         Purcell.Nellies@Demizz.com              2
# 1     Vassili.Andriulis@Brainbox.com              4
# 2        Lind.Oakeshott@Centidel.com              4
# 3        Elie.Rubinfajn@Edgeblab.com              4
# 4          Adela.Benedtti@Trudoo.com              4
# 5     Dalenna.Colebourn@Linktype.com              4
# 6     Arlette.Klimko@Thoughtblab.com              1
# 7  Leontine.Shearwood@Browseblab.com              1
# 8       Evvy.Truswell@Photospace.com              3
# 9        Wendie.Stichall@Kwimbee.com              1

# %%
df2= df[["Academic Year","Pupil's Name","Parental Contact Full Name","Parental Contact Email Address"]]

# %%
df2.head(10)
# Out:
#    Academic Year       Pupil's Name Parental Contact Full Name  \
# 0              2      Nellies,Ronna            Nellies,Purcell
# 1              4    Andriulis,Rusty          Andriulis,Vassili
# 2              4  Oakeshott,Roberta             Oakeshott,Lind
# 3              4     Rubinfajn,Lola             Rubinfajn,Elie
# 4              4    Benedtti,Kamila             Benedtti,Adela
# 5              4    Colebourn,Avery          Colebourn,Dalenna
# 6              1   Klimko,Valentino             Klimko,Arlette
# 7              1      Shearwood,Cal         Shearwood,Leontine
# 8              3      Truswell,King              Truswell,Evvy
# 9              1    Stichall,Towney            Stichall,Wendie
#
#       Parental Contact Email Address
# 0         Purcell.Nellies@Demizz.com
# 1     Vassili.Andriulis@Brainbox.com
# 2        Lind.Oakeshott@Centidel.com
# 3        Elie.Rubinfajn@Edgeblab.com
# 4          Adela.Benedtti@Trudoo.com
# 5     Dalenna.Colebourn@Linktype.com
# 6     Arlette.Klimko@Thoughtblab.com
# 7  Leontine.Shearwood@Browseblab.com
# 8       Evvy.Truswell@Photospace.com
# 9        Wendie.Stichall@Kwimbee.com

# %%
df2.to_csv("2022-Week-1.csv",index = False)
